# %% [markdown]
# Support Vector Machine or SVM is one of the most popular Supervised Learning algorithms, which is used for Classification as well as Regression problems. However, primarily, it is used for Classification problems in Machine Learning.

# %% [markdown]
# The goal of the SVM algorithm is to create the best line or decision boundary that can segregate n-dimensional space into classes so that we can easily put the new data point in the correct category in the future. This best decision boundary is called a hyperplane.

# %% [markdown]
# SVM chooses the extreme points/vectors that help in creating the hyperplane. These extreme cases are called as support vectors, and hence algorithm is termed as Support Vector Machine. Consider the below diagram in which there are two different categories that are classified using a decision boundary or hyperplane:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example: SVM can be understood with the example that we have used in the KNN classifier. Suppose we see a strange cat that also has some features of dogs, so if we want a model that can accurately identify whether it is a cat or dog, so such a model can be created by using the SVM algorithm. We will first train our model with lots of images of cats and dogs so that it can learn about different features of cats and dogs, and then we test it with this strange creature. So as support vector creates a decision boundary between these two data (cat and dog) and choose extreme cases (support vectors), it will see the extreme case of cat and dog. On the basis of the support vectors, it will classify it as a cat. Consider the below diagram:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SVM algorithm can be used for Face detection, image classification, text categorization, etc.

# %% [markdown]
# **Types of SVM**

# %% [markdown]
# SVM can be of two types:

# %% [markdown]
# **Linear SVM:** Linear SVM is used for linearly separable data, which means if a dataset can be classified into two classes by using a single straight line, then such data is termed as linearly separable data, and classifier is used called as Linear SVM classifier.

# %% [markdown]
# **Non-linear SVM:** Non-Linear SVM is used for non-linearly separated data, which means if a dataset cannot be classified by using a straight line, then such data is termed as non-linear data and classifier used is called as Non-linear SVM classifier.

# %% [markdown]
# **Hyperplane and Support Vectors in the SVM algorithm:**

# %% [markdown]
# Hyperplane: There can be multiple lines/decision boundaries to segregate the classes in n-dimensional space, but we need to find out the best decision boundary that helps to classify the data points. This best boundary is known as the hyperplane of SVM.

# %% [markdown]
# The dimensions of the hyperplane depend on the features present in the dataset, which means if there are 2 features (as shown in image), then hyperplane will be a straight line. And if there are 3 features, then hyperplane will be a 2-dimension plane.

# %% [markdown]
# We always create a hyperplane that has a maximum margin, which means the maximum distance between the data points.

# %% [markdown]
# **Support Vectors:**

# %% [markdown]
# The data points or vectors that are the closest to the hyperplane and which affect the position of the hyperplane are termed as Support Vector. Since these vectors support the hyperplane, hence called a Support vector.

# %% [markdown]
# **How does SVM works?**

# %% [markdown]
# The working of the SVM algorithm can be understood by using an example. Suppose we have a dataset that has two tags (green and blue), and the dataset has two features x1 and x2. We want a classifier that can classify the pair(x1, x2) of coordinates in either green or blue. Consider the below image:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So as it is 2-d space so by just using a straight line, we can easily separate these two classes. But there can be multiple lines that can separate these classes. Consider the below image:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hence, the SVM algorithm helps to find the best line or decision boundary; this best boundary or region is called as a hyperplane. SVM algorithm finds the closest point of the lines from both the classes. These points are called support vectors. The distance between the vectors and the hyperplane is called as margin. And the goal of SVM is to maximize this margin. The hyperplane with maximum margin is called the optimal hyperplane.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Non-Linear SVM:**

# %% [markdown]
# If data is linearly arranged, then we can separate it by using a straight line, but for non-linear data, we cannot draw a single straight line. Consider the below image:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So to separate these data points, we need to add one more dimension. For linear data, we have used two dimensions x and y, so for non-linear data, we will add a third dimension z. It can be calculated as:

# %% [markdown]
# z=x2 +y2

# %% [markdown]
# By adding the third dimension, the sample space will become as below image:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So now, SVM will divide the datasets into classes in the following way. Consider the below image:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Since we are in 3-d Space, hence it is looking like a plane parallel to the x-axis. If we convert it in 2d space with z=1, then it will become as:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hence we get a circumference of radius 1 in case of non-linear data.

# %% [markdown]
# **Python Implementation of Support Vector Machine**

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Define Typography**

# %% [markdown]
# > the style and appearance of printed matter.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
letters = pd.read_csv(r'letters.csv')
letters.head()
# Out:
#   lettr  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0     T      2      8      3     5      1      8     13      0      6      6
# 1     I      5     12      3     7      2     10      5      5      4     13
# 2     D      4     11      6     8      6     10      6      2      6     10
# 3     N      7     11      6     6      3      5      9      4      6      4
# 4     G      2      1      3     1      1      8      6      6      6      6
#
#    x2ybar  xy2bar  x-ege  xegvy  y-ege  yegvx
# 0      10       8      0      8      0      8
# 1       3       9      2      8      4     10
# 2       3       7      3      7      3      9
# 3       4      10      6     10      2      8
# 4       5       9      1      7      5     10

# %%
letters
# Out:
#       lettr  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  \
# 0         T      2      8      3     5      1      8     13      0      6
# 1         I      5     12      3     7      2     10      5      5      4
# 2         D      4     11      6     8      6     10      6      2      6
# 3         N      7     11      6     6      3      5      9      4      6
# 4         G      2      1      3     1      1      8      6      6      6
# ...     ...    ...    ...    ...   ...    ...    ...    ...    ...    ...
# 19995     D      2      2      3     3      2      7      7      7      6
# 19996     C      7     10      8     8      4      4      8      6      9
# 19997     T      6      9      6     7      5      6     11      3      7
# 19998     S      2      3      4     2      1      8      7      2      6
# 19999     A      4      9      6     6      2      9      5      3      1
#
#        xybar  x2ybar  xy2bar  x-ege  xegvy  y-ege  yegvx
# 0          6      10       8      0      8      0      8
# 1         13       3       9      2      8      4     10
# 2         10       3       7      3      7      3      9
# 3          4       4      10      6     10      2      8
# 4          6       5       9      1      7      5     10
# ...      ...     ...     ...    ...    ...    ...    ...
# 19995      6       6       4      2      8      3      7
# 19996     12       9      13      2      9      3      7
# 19997     11       9       5      2     12      2      4
# 19998     10       6       8      1      9      5      8
# 19999      8       1       8      2      7      2      8
#
# [20000 rows x 17 columns]

# %%
letters.columns
# Out:
# Index(['lettr', 'x-box', 'y-box', 'width', 'high', 'onpix', 'x-bar', 'y-bar',
#        'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'x-ege', 'xegvy',
#        'y-ege', 'yegvx'],
#       dtype='object')

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
train,test =train_test_split(letters,test_size=0.3)

# %%
train_X = train.iloc[:,1:]
train_X
# Out:
#        x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 12379      5      9      7     8      8      5      6      4      5      7
# 18765      4      4      5     3      3      7      6      6      5      6
# 7366       4      6      6     6      6      8      8      5      5      7
# 8006       3      4      5     3      2      6     11      5      2     12
# 6572       1      0      1     1      0      6      7      6      8      7
# ...      ...    ...    ...   ...    ...    ...    ...    ...    ...    ...
# 15159      3     11      4     8      2      6      8      0      8     13
# 15833      5      8      6     6      5      8      8      5      6     10
# 1313       7     11      4     6      2      8      7      5      8     10
# 18592      5     11      9     8      7      8      4      1      4      6
# 4241       5     11      6     8      2      5      7      7     10      7
#
#        x2ybar  xy2bar  x-ege  xegvy  y-ege  yegvx
# 12379       6      11      5     11      8     11
# 18765       7       7      8      6      3      7
# 7366        7       8      4     10      8      9
# 8006        5       2      1     10      3      9
# 6572        6      14      0      8      4     10
# ...       ...     ...    ...    ...    ...    ...
# 15159       7       8      0      8      1      7
# 15833       5       4      4      9      4      9
# 1313        6       9      2     10      7      9
# 18592       2       6      5      8      6      6
# 4241        6      14      1      8      4      9
#
# [14000 rows x 16 columns]

# %%
train_Y = train.iloc[:,0]
train_Y
# Out:
# 12379    C
# 18765    M
# 7366     S
# 8006     P
# 6572     C
#         ..
# 15159    I
# 15833    D
# 1313     E
# 18592    A
# 4241     C
# Name: lettr, Length: 14000, dtype: object

# %%
test_X = test.iloc[:,1:]
test_X
# Out:
#        x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 14452      5     10      6     8      4      8      7      3      6     14
# 3494       6      9      8     7      8      8      4      7      3      7
# 11828      8     12      9     7      5      1      8      2      3      9
# 12077      3      7      5     5      2      8     10      2      6      4
# 12193      2      7      4     5      2     10     10      3      1      6
# ...      ...    ...    ...   ...    ...    ...    ...    ...    ...    ...
# 14201      3      5      5     6      5     10     11      6      3      3
# 13731      9     14      8     8      5      4      9      4      3     11
# 10246      3      7      5     5      2      7      8      6      7      6
# 9435       3      7      4     5      1      6      8      6      9      5
# 18683      4      5      6     4      3      7      8      2      5     10
#
#        x2ybar  xy2bar  x-ege  xegvy  y-ege  yegvx
# 14452       5       9      1      6      1      7
# 3494        6       7      8      7      6      3
# 11828      11       9      9      9      1      6
# 12077      11       9      2     12      2      7
# 12193      12       8      2     11      0      8
# ...       ...     ...    ...    ...    ...    ...
# 14201       8      12      3     10      5     10
# 13731      10       6      4     11      4      5
# 10246      10       9      3      9      1      7
# 9435        6      14      1      7      4      9
# 18683       6       6      5      9      1      7
#
# [6000 rows x 16 columns]

# %%
test_Y = test.iloc[:,0]
test_Y
# Out:
# 14452    J
# 3494     W
# 11828    W
# 12077    Y
# 12193    Y
#         ..
# 14201    Q
# 13731    Y
# 10246    U
# 9435     C
# 18683    N
# Name: lettr, Length: 6000, dtype: object

# %%
from sklearn.svm import SVC
#help(SVC)

# %% [markdown]
# **Linear**

# %%
# create SVM classification obj
# linear
# kernel = linear

model_linear = SVC(kernel="linear")
model_linear.fit(train_X,train_Y)
# Out:
# SVC(kernel='linear')

# %%
pred_test_linear = model_linear.predict(test_X)
pred_test_linear
# Out:
# array(['J', 'N', 'W', ..., 'U', 'C', 'N'], dtype=object)

# %%
test_Y == pred_test_linear  # actual == predicted
# Out:
# 14452     True
# 3494     False
# 11828     True
# 12077     True
# 12193     True
#          ...
# 14201     True
# 13731     True
# 10246     True
# 9435      True
# 18683     True
# Name: lettr, Length: 6000, dtype: bool

# %%
np.mean(test_Y == pred_test_linear)
# Out:
# 0.853

# %%
accuracy_score(test_Y,pred_test_linear) * 100
# Out:
# 85.3

# %% [markdown]
# **Polynomial**

# %%
# create SVM classification obj
# non-linear
# kernel = poly

model_poly = SVC(kernel="poly")
model_poly.fit(train_X,train_Y)
# Out:
# SVC(kernel='poly')

# %%
pred_test_poly = model_poly.predict(test_X)
pred_test_poly
# Out:
# array(['J', 'W', 'W', ..., 'U', 'C', 'N'], dtype=object)

# %%
test_Y == pred_test_poly  # actual == predicted
# Out:
# 14452     True
# 3494      True
# 11828     True
# 12077     True
# 12193    False
#          ...
# 14201     True
# 13731     True
# 10246     True
# 9435      True
# 18683     True
# Name: lettr, Length: 6000, dtype: bool

# %%
np.mean(test_Y == pred_test_poly)
# Out:
# 0.9451666666666667

# %%
accuracy_score(test_Y,pred_test_poly)*100
# Out:
# 94.51666666666667

# %% [markdown]
# **RBF (Radial Basis Function)**

# %%
# create SVM classification obj
# non-linear
# kernel = rbf

model_rbf = SVC(kernel="rbf")
model_rbf.fit(train_X,train_Y)
# Out:
# SVC()

# %%
pred_test_rbf = model_rbf.predict(test_X)
pred_test_rbf
# Out:
# array(['J', 'M', 'W', ..., 'U', 'C', 'N'], dtype=object)

# %%
test_Y == pred_test_rbf  # actual == predicted
# Out:
# 14452     True
# 3494     False
# 11828     True
# 12077     True
# 12193    False
#          ...
# 14201     True
# 13731     True
# 10246     True
# 9435      True
# 18683     True
# Name: lettr, Length: 6000, dtype: bool

# %%
np.mean(test_Y == pred_test_rbf) # actual == predicted
# Out:
# 0.9191666666666667

# %%
accuracy_score(test_Y,pred_test_rbf) * 100
# Out:
# 91.91666666666667
