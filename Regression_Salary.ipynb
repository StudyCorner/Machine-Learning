# %%
#Checking the current working directory or set the working directory:
import os
os.getcwd()
#os.chdir('F:\\2020\\Learning_Solutions\\Batch-2\\Day2')
# Out:
# 'd:\\DS\\regression'

# %%
#Load the pandas:
import pandas as pd

# %%
#Load the dataset:
data = pd.read_excel('Salary.xlsx',sheet_name = 0)
data
# Out:
#    Experience  Salary
# 0          15    3000
# 1          18    3600
# 2          20    4000
# 3          22    4400
# 4          24    4800
# 5          28    5600
# 6          29    5800
# 7          84   16800
# 8          73   14600

# %%
#Split the train and test:
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data[["Experience"]],data[["Salary"]],random_state = 1)

# %%
X_train
# Out:
#    Experience
# 7          84
# 1          18
# 0          15
# 4          24
# 3          22
# 5          28

# %%
X_test
# Out:
#    Experience
# 8          73
# 2          20
# 6          29

# %%
y_train
# Out:
#    Salary
# 7   16800
# 1    3600
# 0    3000
# 4    4800
# 3    4400
# 5    5600

# %%
y_test
# Out:
#    Salary
# 8   14600
# 2    4000
# 6    5800

# %%
#Build the Linear Regression:
from sklearn.linear_model import LinearRegression
Model = LinearRegression()

# %%
#Model Building:
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Predict on test:
y_pred = Model.predict(X_test)
y_pred
# Out:
# array([[14600.],
#        [ 4000.],
#        [ 5800.]])

# %%
y_test
# Out:
#    Salary
# 8   14600
# 2    4000
# 6    5800

# %%
#Check the Metrics:
from sklearn.metrics import mean_absolute_error,mean_squared_error,median_absolute_error
mean_absolute_error(y_test,y_pred)
# Out:
# 9.094947017729282e-13

# %%
y_pred,y_test
# Out:
# (array([[14600.],
#         [ 4000.],
#         [ 5800.]]),
#     Salary
#  8   14600
#  2    4000
#  6    5800)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.3786343542550462e-24

# %%
median_absolute_error(y_test,y_pred)
# Out:
# 9.094947017729282e-13
