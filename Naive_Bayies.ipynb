# %% [markdown]
# Naïve Bayes algorithm is a supervised learning algorithm, which is based on Bayes theorem and used for solving classification problems.

# %% [markdown]
# It is mainly used in text classification that includes a high-dimensional training dataset.

# %% [markdown]
# Naïve Bayes Classifier is one of the simple and most effective Classification algorithms which helps in building the fast machine learning models that can make quick predictions.

# %% [markdown]
# It is a probabilistic classifier, which means it predicts on the basis of the probability of an object.

# %% [markdown]
# Some popular examples of Naïve Bayes Algorithm are spam filtration, Sentimental analysis, and classifying articles.

# %% [markdown]
# **Why is it called Naïve Bayes?**

# %% [markdown]
# The Naïve Bayes algorithm is comprised of two words Naïve and Bayes, Which can be described as:

# %% [markdown]
# **Naïve:** It is called Naïve because it assumes that the occurrence of a certain feature is independent of the occurrence of other features. Such as if the fruit is identified on the bases of color, shape, and taste, then red, spherical, and sweet fruit is recognized as an apple. Hence each feature individually contributes to identify that it is an apple without depending on each other.

# %% [markdown]
# Bayes: It is called Bayes because it depends on the principle of Bayes' Theorem.

# %% [markdown]
# **Bayes' Theorem:**

# %% [markdown]
# Bayes' theorem is also known as Bayes' Rule or Bayes' law, which is used to determine the probability of a hypothesis with prior knowledge. It depends on the conditional probability.

# %% [markdown]
# The formula for Bayes' theorem is given as:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Where,

# %% [markdown]
# P(A|B) is Posterior probability: Probability of hypothesis A on the observed event B.

# %% [markdown]
# P(B|A) is Likelihood probability: Probability of the evidence given that the probability of a hypothesis is true.

# %% [markdown]
# P(A) is Prior Probability: Probability of hypothesis before observing the evidence.

# %% [markdown]
# P(B) is Marginal Probability: Probability of Evidence.

# %% [markdown]
# **Working of Naïve Bayes' Classifier:**

# %% [markdown]
# Working of Naïve Bayes' Classifier can be understood with the help of the below example:

# %% [markdown]
# Suppose we have a dataset of weather conditions and corresponding target variable "Play". So using this dataset we need to decide that whether we should play or not on a particular day according to the weather conditions. So to solve this problem, we need to follow the below steps:

# %% [markdown]
# > Convert the given dataset into frequency tables.
#
#
# > Generate Likelihood table by finding the probabilities of given features.
#
#
# > Now, use Bayes theorem to calculate the posterior probability.

# %% [markdown]
# Problem: If the weather is sunny, then the Player should play or not?

# %% [markdown]
# Solution: To solve this, first consider the below dataset:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Hence on a Sunny day, Player can play the game.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Implementation**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
iris = pd.read_csv(r"iris.csv")
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
ip_columns = ['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width']  # x
op_columns = ["Species"] # y

# %%
# splitting data into train and test

Xtrain,Xtest,Ytrain,Ytest = train_test_split(iris[ip_columns],iris[op_columns],test_size = 0.3,random_state=0)

# %%
Xtrain
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 60            5.0          2.0           3.5          1.0
# 116           6.5          3.0           5.5          1.8
# 144           6.7          3.3           5.7          2.5
# 119           6.0          2.2           5.0          1.5
# 108           6.7          2.5           5.8          1.8
# ..            ...          ...           ...          ...
# 9             4.9          3.1           1.5          0.1
# 103           6.3          2.9           5.6          1.8
# 67            5.8          2.7           4.1          1.0
# 117           7.7          3.8           6.7          2.2
# 47            4.6          3.2           1.4          0.2
#
# [105 rows x 4 columns]

# %%
Ytrain
# Out:
#         Species
# 60   versicolor
# 116   virginica
# 144   virginica
# 119   virginica
# 108   virginica
# ..          ...
# 9        setosa
# 103   virginica
# 67   versicolor
# 117   virginica
# 47       setosa
#
# [105 rows x 1 columns]

# %%
Xtest
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 114           5.8          2.8           5.1          2.4
# 62            6.0          2.2           4.0          1.0
# 33            5.5          4.2           1.4          0.2
# 107           7.3          2.9           6.3          1.8
# 7             5.0          3.4           1.5          0.2
# 100           6.3          3.3           6.0          2.5
# 40            5.0          3.5           1.3          0.3
# 86            6.7          3.1           4.7          1.5
# 76            6.8          2.8           4.8          1.4
# 71            6.1          2.8           4.0          1.3
# 134           6.1          2.6           5.6          1.4
# 51            6.4          3.2           4.5          1.5
# 73            6.1          2.8           4.7          1.2
# 54            6.5          2.8           4.6          1.5
# 63            6.1          2.9           4.7          1.4
# ...

# %%
Ytest
# Out:
#         Species
# 114   virginica
# 62   versicolor
# 33       setosa
# 107   virginica
# 7        setosa
# 100   virginica
# 40       setosa
# 86   versicolor
# 76   versicolor
# 71   versicolor
# 134   virginica
# 51   versicolor
# 73   versicolor
# 54   versicolor
# 63   versicolor
# 37       setosa
# 78   versicolor
# 90   versicolor
# 45       setosa
# 16       setosa
# 121   virginica
# 66   versicolor
# 24       setosa
# 8        setosa
# 126   virginica
# 22       setosa
# 44       setosa
# 97   versicolor
# 93   versicolor
# 26       setosa
# 137   virginica
# 84   versicolor
# 27       setosa
# 127   virginica
# 132   virginica
# 59   versicolor
# 18       setosa
# 83   versicolor
# 61   versicolor
# 92   versicolor
# 112   virginica
# 2        setosa
# 141   virginica
# 43       setosa
# 10       setosa

# %%
len(Ytest)
# Out:
# 45

# %%
(150 * 30)/100
# Out:
# 45.0

# %%
imnb = MultinomialNB()

# %%
help(MultinomialNB)

# %%
Xtrain.iloc[0:3,:]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 60            5.0          2.0           3.5          1.0
# 116           6.5          3.0           5.5          1.8
# 144           6.7          3.3           5.7          2.5

# %%
Ytrain.iloc[0:3,:]
# Out:
#         Species
# 60   versicolor
# 116   virginica
# 144   virginica

# %%
# building and predicting at the same time

pred_mnb = imnb.fit(Xtrain.iloc[:,0:4],Ytrain.iloc[:,0]) # 105 records
pred_mnb
# Out:
# MultinomialNB()

# %%
Y_train_pred = pred_mnb.predict(Xtrain.iloc[:,0:4])
Y_train_pred
# Out:
# array(['virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'setosa', 'setosa',
#        'virginica', 'virginica', 'setosa', 'setosa', 'virginica',
#        'setosa', 'virginica', 'virginica', 'setosa', 'virginica',
#        'virginica', 'virginica', 'setosa', 'virginica', 'virginica',
#        'virginica', 'virginica', 'setosa', 'setosa', 'virginica',
#        'virginica', 'setosa', 'virginica', 'setosa', 'virginica',
#        'virginica', 'setosa', 'setosa', 'virginica', 'setosa', 'setosa',
#        'setosa', 'virginica', 'virginica', 'virginica', 'setosa',
#        'setosa', 'setosa', 'virginica', 'virginica', 'setosa', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
# ...

# %%
pred_mnb.predict_proba(Xtrain.iloc[:,0:4])
# Out:
# array([[0.07398013, 0.43428162, 0.49173825],
#        [0.01404309, 0.42924057, 0.55671634],
#        [0.00561425, 0.40080299, 0.59358276],
#        [0.01731315, 0.42386867, 0.55881817],
#        [0.00865549, 0.41468479, 0.57665971],
#        [0.07298015, 0.44529967, 0.48172018],
#        [0.00570018, 0.41397266, 0.58032716],
#        [0.0383343 , 0.45179208, 0.50987362],
#        [0.07257803, 0.44307472, 0.48434724],
#        [0.01761099, 0.42861728, 0.55377174],
#        [0.0244627 , 0.44110128, 0.53443602],
#        [0.01800637, 0.41068076, 0.57131287],
#        [0.01259542, 0.41726255, 0.57014203],
#        [0.05458466, 0.46560279, 0.47981255],
#        [0.01327393, 0.42475223, 0.56197384],
#        [0.04417397, 0.4505078 , 0.50531823],
#        [0.65397682, 0.20295398, 0.14306919],
#        [0.01184401, 0.41148579, 0.5766702 ],
#        [0.05065483, 0.44390377, 0.5054414 ],
#        [0.08652083, 0.4448764 , 0.46860277],
#        [0.05109345, 0.44063072, 0.50827583],
# ...

# %%
confusion_matrix(Ytrain,Y_train_pred)
# Out:
# array([[34,  0,  0],
#        [ 0,  1, 31],
#        [ 0,  0, 39]])

# %%
pd.crosstab(Ytrain.iloc[:,0],Y_train_pred)
# Out:
# col_0       setosa  versicolor  virginica
# Species
# setosa          34           0          0
# versicolor       0           1         31
# virginica        0           0         39

# %%
accuracy_score(Ytrain.iloc[:,0],Y_train_pred)
# Out:
# 0.7047619047619048

# %%
Y_pred = pred_mnb.predict(Xtest.iloc[:,0:4])
Y_pred
# Out:
# array(['virginica', 'virginica', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'setosa', 'virginica', 'virginica', 'setosa', 'setosa',
#        'virginica', 'virginica', 'setosa', 'setosa', 'virginica',
#        'setosa', 'setosa', 'virginica', 'virginica', 'setosa',
#        'virginica', 'virginica', 'setosa', 'virginica', 'virginica',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'setosa', 'virginica', 'setosa', 'setosa'],
#       dtype='<U10')

# %%
pred_mnb.predict_proba(Xtest.iloc[:,0:4])
# Out:
# array([[0.00619004, 0.38840282, 0.60540714],
#        [0.07094938, 0.44887038, 0.48018024],
#        [0.82816037, 0.10901846, 0.06282117],
#        [0.00859835, 0.42645261, 0.56494905],
#        [0.71676758, 0.17021219, 0.11302023],
#        [0.00409881, 0.38738418, 0.608517  ],
#        [0.73060417, 0.16229946, 0.10709638],
#        [0.04242334, 0.45749311, 0.50008356],
#        [0.03876742, 0.45623808, 0.5049945 ],
#        [0.06828472, 0.45177549, 0.47993978],
#        [0.01651043, 0.42989044, 0.55359913],
#        [0.048852  , 0.45587617, 0.49527183],
#        [0.04740026, 0.4523734 , 0.50022634],
#        [0.03680154, 0.45018398, 0.51301448],
#        [0.03829779, 0.44817663, 0.51352558],
#        [0.77533402, 0.13759325, 0.08707273],
#        [0.03786911, 0.44519127, 0.51693963],
#        [0.04643884, 0.44252061, 0.51104055],
#        [0.64284225, 0.20800593, 0.14915182],
#        [0.76407235, 0.14520233, 0.09072532],
#        [0.01216442, 0.40905678, 0.5787788 ],
# ...

# %%
# confusion matrix is a model for finding out the performance of a classification model

# confusion matrix multinomial model

confusion_matrix(Ytest,Y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0,  0, 18],
#        [ 0,  0, 11]])

# %%
pd.crosstab(Ytest.iloc[:,0],Y_pred)
# Out:
# col_0       setosa  virginica
# Species
# setosa          16          0
# versicolor       0         18
# virginica        0         11

# %%
accuracy_score(Ytrain.iloc[:,0],Y_train_pred) # model works well at training
# Out:
# 0.7047619047619048

# %%
accuracy_score(Ytest.iloc[:,0],Y_pred) # not at testing
# Out:
# 0.6

# %% [markdown]
# Over fit : works only for  my training data and testing data(it will not be reliable for new data points) ( low bias , high variance)

# %% [markdown]
# Under Fit : it will not work well on  your training data but good for  testing data ( high bias and low variance)

# %% [markdown]
# Best Fit : works well training data testing data and for new data data and it can balance everything
